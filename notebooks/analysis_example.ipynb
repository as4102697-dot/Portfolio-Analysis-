# %% [markdown]
# # Stock Portfolio Analysis Example
#
# This notebook demonstrates how to use the portfolio analysis tools to analyze your stock holdings.

# %% [markdown]
# ## Step 1: Import Libraries and Load Data

# %%
import sys
sys.path.append('..')

from src.portfolio_analysis import PortfolioAnalyzer
from src.visualizations import PortfolioVisualizer
import pandas as pd

# %% [markdown]
# ## Step 2: Initialize the Analyzer

# %%
# Create analyzer instance
analyzer = PortfolioAnalyzer('../data/portfolio.csv')

# %% [markdown]
# ## Step 3: Generate Analysis Report

# %%
# Get comprehensive portfolio summary
summary = analyzer.get_summary_report()

# %% [markdown]
# ## Step 4: Individual Stock Performance

# %%
# Get individual stock returns
individual_returns = analyzer.calculate_individual_returns()
print(individual_returns.to_string())

# %% [markdown]
# ## Step 5: Portfolio Allocation

# %%
# Get portfolio allocation
allocation = analyzer.calculate_portfolio_allocation()
print(allocation.to_string())

# %% [markdown]
# ## Step 6: Generate Visualizations

# %%
# Create visualizations
visualizer = PortfolioVisualizer('../data/portfolio.csv')
visualizer.generate_all_charts()

# %% [markdown]
# ## Step 7: Export Results

# %%
# Export analysis to CSV
analyzer.export_analysis_to_csv('../output')
